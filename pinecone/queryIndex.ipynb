# %%
import pinecone
import os

api_key = "881ad1dd-9ab5-4406-baea-6a64f034c64e"
pinecone.init(api_key=api_key, environment='asia-southeast1-gcp-free')
# Out:
# c:\Users\zhouxy\Anaconda3\lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
pinecone.list_indexes()
# Out:
# ['rules']

# %%
pinecone.describe_index("rules")
# Out:
# IndexDescription(name='rules', metric='cosine', replicas=1, dimension=1536.0, shards=1, pods=1, pod_type='p1', status={'ready': True, 'state': 'Ready'}, metadata_config=None, source_collection='')

# %%
index = pinecone.Index("rules")

index.fetch(ids = ['999c5659-e84b-4947-990d-62f4ae449245'], namespace="soc-project")
# Out:
# {'namespace': 'soc-project', 'vectors': {}}

# %%
import random
queries = [[random.random() for _ in range(128)] for _ in range(12)]

# %%
index.query(queries, top_k=3, include_metadata=True, namespace="soc-project", filter={'source':{'$eq':'C:\\gpt4-pdf-chatbot-langchain\\docs\\游戏开发环境与工作流说明.pdf'}})
# Out:
# {'matches': [{'id': '999c5659-e84b-4947-990d-62f4ae449245',
#               'metadata': {'loc.lines.from': 1.0,
#                            'loc.lines.to': 303.0,
#                            'loc.pageNumber': 1.0,
#                            'pdf.info.CreationDate': "D:20230608064127+00'00'",
#                            'pdf.info.Creator': 'Chromium',
#                            'pdf.info.IsAcroFormPresent': False,
#                            'pdf.info.IsXFAPresent': False,
#                            'pdf.info.ModDate': "D:20230608064127+00'00'",
#                            'pdf.info.PDFFormatVersion': '1.4',
#                            'pdf.info.Producer': 'Skia/PDF m107',
#                            'pdf.totalPages': 3.0,
#                            'pdf.version': datetime.date(100, 1, 10),
#                            'source': 'C:\\gpt4-pdf-chatbot-langchain\\docs\\游戏开发环境与工作流说明.pdf',
#                            'text': '1\n'
#                                    ' \n'
#                                    '/ \n'
#                                    '3\n'
#                                    '关\n'
#                                    '键\n'
#                                    '词\n'
#                                    '：\n'
#                                    '游\n'
#                                    '戏\n'
#                                    '开\n'
#                                    '发\n'
#                                    '、\n'
#                                    '环\n'
#                                    '境\n'
#                                    '、\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '、\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '环\n'
#                                    '境\n'
#                                    '、\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '、\n'
#                                    '工\n'
#                                    '作\n'
#                                    '流\n'
#                                    '、\n'
#                                    '体\n'
#                                    '验\n'
#                                    '游\n'
#                                    '戏\n'
#                                    '本\n'
#                                    '文\n'
#                                    '介\n'
#                                    '绍\n'
#                                    '了\n'
#                                    '游\n'
#                                    '戏\n'
#                                    '开\n'
#                                    '发\n'
#                                    '中\n'
#                                    '需\n'
#                                    '要\n'
#                                    '用\n'
#                                    '到\n'
#                                    '的\n'
#                                    '各\n'
#                                    '种\n'
#                                    '环\n'
#                                    '境\n'
#                                    '和\n'
#                                    '工\n'
#                                    '具\n'
#                                    '，\n'
#                                    '包\n'
#                                    '括\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '、\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '环\n'
#                                    '境\n'
#                                    '、\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '等\n'
#                                    '，\n'
#                                    '并\n'
#                                    '针\n'
#                                    '对\n'
#                                    '不\n'
#                                    '同\n'
#                                    '的\n'
#                                    '任\n'
#                                    '务\n'
#                                    '目\n'
#                                    '标\n'
#                                    '提\n'
#                                    '供\n'
#                                    '了\n'
#                                    '相\n'
#                                    '应\n'
#                                    '的\n'
#                                    '验\n'
#                                    '收\n'
#                                    '/\n'
#                                    '测\n'
#                                    '试\n'
#                                    '环\n'
#                                    '境\n'
#                                    '和\n'
#                                    '使\n'
#                                    '用\n'
#                                    '方\n'
#                                    '式\n'
#                                    '。\n'
#                                    '同\n'
#                                    '时\n'
#                                    '还\n'
#                                    '介\n'
#                                    '绍\n'
#                                    '了\n'
#                                    '团\n'
#                                    '队\n'
#                                    '主\n'
#                                    '要\n'
#                                    '的\n'
#                                    '工\n'
#                                    '作\n'
#                                    '流\n'
#                                    '以\n'
#                                    '及\n'
#                                    '相\n'
#                                    '关\n'
#                                    '接\n'
#                                    '口\n'
#                                    '人\n'
#                                    '文\n'
#                                    '档\n'
#                                    '。\n'
#                                    '最\n'
#                                    '后\n'
#                                    '还\n'
#                                    '提\n'
#                                    '供\n'
#                                    '了\n'
#                                    '获\n'
#                                    '取\n'
#                                    '手\n'
#                                    '机\n'
#                                    '体\n'
#                                    '验\n'
#                                    '包\n'
#                                    '的\n'
#                                    '链\n'
#                                    '接\n'
#                                    '，\n'
#                                    '供\n'
#                                    '用\n'
#                                    '户\n'
#                                    '下\n'
#                                    '载\n'
#                                    '体\n'
#                                    '验\n'
#                                    '。\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '是\n'
#                                    '开\n'
#                                    '发\n'
#                                    '的\n'
#                                    '起\n'
#                                    '点\n'
#                                    '，\n'
#                                    '本\n'
#                                    '地\n'
#                                    '所\n'
#                                    '有\n'
#                                    '的\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '都\n'
#                                    '是\n'
#                                    '远\n'
#                                    '端\n'
#                                    '的\n'
#                                    '目\n'
#                                    '录\n'
#                                    '一\n'
#                                    '份\n'
#                                    '镜\n'
#                                    '像\n'
#                                    '，\n'
#                                    '使\n'
#                                    '用\n'
#                                    'git/svn\n'
#                                    '进\n'
#                                    '行\n'
#                                    '同\n'
#                                    '步\n'
#                                    '和\n'
#                                    '管\n'
#                                    '理\n'
#                                    '。\n'
#                                    ' \n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '环\n'
#                                    '境\n'
#                                    '在\n'
#                                    '启\n'
#                                    '动\n'
#                                    '客\n'
#                                    '户\n'
#                                    '端\n'
#                                    '之\n'
#                                    '后\n'
#                                    '，\n'
#                                    '会\n'
#                                    '选\n'
#                                    '择\n'
#                                    '要\n'
#                                    '连\n'
#                                    '接\n'
#                                    '的\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '，\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '的\n'
#                                    '说\n'
#                                    '明\n'
#                                    '⻅\n'
#                                    '，\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '上\n'
#                                    '运\n'
#                                    '行\n'
#                                    '着\n'
#                                    '来\n'
#                                    '自\n'
#                                    '不\n'
#                                    '同\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '的\n'
#                                    '资\n'
#                                    '源\n'
#                                    '，\n'
#                                    '公\n'
#                                    '共\n'
#                                    '服\n'
#                                    '目\n'
#                                    '前\n'
#                                    '由\n'
#                                    '测\n'
#                                    '试\n'
#                                    '同\n'
#                                    '学\n'
#                                    '负\n'
#                                    '责\n'
#                                    '维\n'
#                                    '护\n'
#                                    '。\n'
#                                    '游\n'
#                                    '戏\n'
#                                    '开\n'
#                                    '发\n'
#                                    '环\n'
#                                    '境\n'
#                                    '与\n'
#                                    '工\n'
#                                    '作\n'
#                                    '流\n'
#                                    '说\n'
#                                    '明\n'
#                                    '游\n'
#                                    '戏\n'
#                                    '开\n'
#                                    '发\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '说\n'
#                                    '明\n'
#                                    '地\n'
#                                    '图\n'
#                                    'ID\n'
#                                    '与\n'
#                                    '地\n'
#                                    '图\n'
#                                    '配\n'
#                                    '置'},
#               'score': -0.0190662,
#               'values': []},
#              {'id': '0e0aacd8-9f72-43de-acb1-27ffdc01eeea',
#               'metadata': {'loc.lines.from': 1.0,
#                            'loc.lines.to': 321.0,
#                            'loc.pageNumber': 2.0,
#                            'pdf.info.CreationDate': "D:20230608064127+00'00'",
#                            'pdf.info.Creator': 'Chromium',
#                            'pdf.info.IsAcroFormPresent': False,
#                            'pdf.info.IsXFAPresent': False,
#                            'pdf.info.ModDate': "D:20230608064127+00'00'",
#                            'pdf.info.PDFFormatVersion': '1.4',
#                            'pdf.info.Producer': 'Skia/PDF m107',
#                            'pdf.totalPages': 3.0,
#                            'pdf.version': datetime.date(100, 1, 10),
#                            'source': 'C:\\gpt4-pdf-chatbot-langchain\\docs\\游戏开发环境与工作流说明.pdf',
#                            'text': '2\n'
#                                    ' \n'
#                                    '/ \n'
#                                    '3\n'
#                                    '验\n'
#                                    '收\n'
#                                    '\\\n'
#                                    '测\n'
#                                    '试\n'
#                                    '环\n'
#                                    '境\n'
#                                    '和\n'
#                                    '使\n'
#                                    '用\n'
#                                    '方\n'
#                                    '式\n'
#                                    '注\n'
#                                    '1\n'
#                                    '：\n'
#                                    '指\n'
#                                    '在\n'
#                                    '本\n'
#                                    '地\n'
#                                    '开\n'
#                                    '启\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '，\n'
#                                    '但\n'
#                                    '是\n'
#                                    '使\n'
#                                    '用\n'
#                                    '的\n'
#                                    '文\n'
#                                    '件\n'
#                                    '来\n'
#                                    '自\n'
#                                    '于\n'
#                                    'SVN\n'
#                                    '上\n'
#                                    '最\n'
#                                    '新\n'
#                                    '编\n'
#                                    '译\n'
#                                    '成\n'
#                                    '功\n'
#                                    '的\n'
#                                    '版\n'
#                                    '本\n'
#                                    '。\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '的\n'
#                                    '说\n'
#                                    '明\n'
#                                    '文\n'
#                                    '档\n'
#                                    ' \n'
#                                    ' \n'
#                                    'A4\n'
#                                    '以\n'
#                                    '及各\n'
#                                    '类\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '的\n'
#                                    '说\n'
#                                    '明\n'
#                                    '文\n'
#                                    '档\n'
#                                    ' \n'
#                                    '任\n'
#                                    '务\n'
#                                    '目\n'
#                                    '标\n'
#                                    '-\n'
#                                    '针\n'
#                                    '对\n'
#                                    '策\n'
#                                    '划\n'
#                                    '客\n'
#                                    '户\n'
#                                    '端\n'
#                                    '环\n'
#                                    '境\n'
#                                    '服\n'
#                                    '务\n'
#                                    '器\n'
#                                    '环\n'
#                                    '境\n'
#                                    '资\n'
#                                    '源\n'
#                                    '包\n'
#                                    '路\n'
#                                    '径\n'
#                                    '表\n'
#                                    '格\n'
#                                    '路\n'
#                                    '径\n'
#                                    '热\n'
#                                    '更\n'
#                                    '新\n'
#                                    '研\n'
#                                    '发\n'
#                                    '期\n'
#                                    '功\n'
#                                    '能\n'
#                                    '开\n'
#                                    '发\n'
#                                    '\\\n'
#                                    '验\n'
#                                    '收\n'
#                                    'Editor\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    'Editor\n'
#                                    '版\n'
#                                    '本\n'
#                                    '地\n'
#                                    'SocAsset\n'
#                                    '目\n'
#                                    '录\n'
#                                    '（\n'
#                                    '可\n'
#                                    '切\n'
#                                    '换\n'
#                                    '使\n'
#                                    '用\n'
#                                    '远\n'
#                                    '程\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '）\n'
#                                    '本\n'
#                                    '地\n'
#                                    '转\n'
#                                    '表\n'
#                                    '文\n'
#                                    '件\n'
#                                    'SocCommon\n'
#                                    '目\n'
#                                    '录\n'
#                                    '支\n'
#                                    '持\n'
#                                    '研\n'
#                                    '发\n'
#                                    '期\n'
#                                    '功\n'
#                                    '能\n'
#                                    '验\n'
#                                    '收\n'
#                                    '手\n'
#                                    '机\n'
#                                    '包\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    'Editor\n'
#                                    '版\n'
#                                    '本\n'
#                                    '地\n'
#                                    'SocAsset\n'
#                                    '目\n'
#                                    '录\n'
#                                    '（\n'
#                                    '可\n'
#                                    '切\n'
#                                    '换\n'
#                                    '使\n'
#                                    '用\n'
#                                    '远\n'
#                                    '程\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '）\n'
#                                    '本\n'
#                                    '地\n'
#                                    '转\n'
#                                    '表\n'
#                                    '文\n'
#                                    '件\n'
#                                    'SocCommon\n'
#                                    '目\n'
#                                    '录\n'
#                                    '支\n'
#                                    '持\n'
#                                    '本\n'
#                                    '机\n'
#                                    '预\n'
#                                    '览\n'
#                                    '最\n'
#                                    '新\n'
#                                    '版\n'
#                                    '本\n'
#                                    'exe\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    'Windows\n'
#                                    '版\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '（\n'
#                                    '表\n'
#                                    '格\n'
#                                    '可\n'
#                                    '切\n'
#                                    '换\n'
#                                    '为\n'
#                                    '本\n'
#                                    '地\n'
#                                    '表\n'
#                                    '）\n'
#                                    '支\n'
#                                    '持\n'
#                                    '功\n'
#                                    '能\n'
#                                    '测\n'
#                                    '试\n'
#                                    'exe\n'
#                                    'A4\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '不\n'
#                                    '支\n'
#                                    '持\n'
#                                    '手\n'
#                                    '机\n'
#                                    '包\n'
#                                    '测\n'
#                                    '试\n'
#                                    '手\n'
#                                    '机\n'
#                                    '包\n'
#                                    'A4\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '不\n'
#                                    '支\n'
#                                    '持\n'
#                                    'showcase\n'
#                                    '手\n'
#                                    '机\n'
#                                    '包\n'
#                                    'stable\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '打\n'
#                                    '包\n'
#                                    '之\n'
#                                    '后\n'
#                                    '的\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '不\n'
#                                    '支\n'
#                                    '持\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '工\n'
#                                    '具\n'
#                                    'Windows\n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '工\n'
#                                    '具\n'
#                                    '地\n'
#                                    '图\n'
#                                    'ID\n'
#                                    '与\n'
#                                    '地\n'
#                                    '图\n'
#                                    '配\n'
#                                    '置'},
#               'score': -0.0201139972,
#               'values': []},
#              {'id': 'c7c284a7-5a55-4a65-8f16-ffdc08fa86b2',
#               'metadata': {'loc.lines.from': 1.0,
#                            'loc.lines.to': 214.0,
#                            'loc.pageNumber': 3.0,
#                            'pdf.info.CreationDate': "D:20230608064127+00'00'",
#                            'pdf.info.Creator': 'Chromium',
#                            'pdf.info.IsAcroFormPresent': False,
#                            'pdf.info.IsXFAPresent': False,
#                            'pdf.info.ModDate': "D:20230608064127+00'00'",
#                            'pdf.info.PDFFormatVersion': '1.4',
#                            'pdf.info.Producer': 'Skia/PDF m107',
#                            'pdf.totalPages': 3.0,
#                            'pdf.version': datetime.date(100, 1, 10),
#                            'source': 'C:\\gpt4-pdf-chatbot-langchain\\docs\\游戏开发环境与工作流说明.pdf',
#                            'text': '3\n'
#                                    ' \n'
#                                    '/ \n'
#                                    '3\n'
#                                    '体\n'
#                                    '验\n'
#                                    '游\n'
#                                    '戏\n'
#                                    '获\n'
#                                    '取\n'
#                                    '手\n'
#                                    '机\n'
#                                    '体\n'
#                                    '验\n'
#                                    '包\n'
#                                    '，\n'
#                                    '下\n'
#                                    '载连\n'
#                                    '接\n'
#                                    '，\n'
#                                    '具\n'
#                                    '体\n'
#                                    '使\n'
#                                    '用\n'
#                                    '的\n'
#                                    '包\n'
#                                    '体\n'
#                                    '验\n'
#                                    '之\n'
#                                    '前\n'
#                                    '会\n'
#                                    '有\n'
#                                    '通\n'
#                                    '知\n'
#                                    '手\n'
#                                    '游\n'
#                                    '包\n'
#                                    '体\n'
#                                    '浏\n'
#                                    '览\n'
#                                    ' (wd.com)\n'
#                                    ' \n'
#                                    '如\n'
#                                    '果\n'
#                                    '是\n'
#                                    '体\n'
#                                    '验\n'
#                                    '的\n'
#                                    '组\n'
#                                    '织\n'
#                                    '者\n'
#                                    '，\n'
#                                    '需\n'
#                                    '要\n'
#                                    '关\n'
#                                    '注\n'
#                                    '自\n'
#                                    '己\n'
#                                    '的\n'
#                                    '提\n'
#                                    '交\n'
#                                    '最\n'
#                                    '终\n'
#                                    '是\n'
#                                    '否\n'
#                                    '进\n'
#                                    '入\n'
#                                    '了\n'
#                                    'AB\n'
#                                    '包\n'
#                                    '，\n'
#                                    '以\n'
#                                    '下\n'
#                                    '是\n'
#                                    '查\n'
#                                    '看\n'
#                                    '自\n'
#                                    '己\n'
#                                    '的\n'
#                                    '提\n'
#                                    '交\n'
#                                    '是\n'
#                                    '否\n'
#                                    '进\n'
#                                    '入\n'
#                                    'ab\n'
#                                    '包\n'
#                                    '的\n'
#                                    '方\n'
#                                    '法\n'
#                                    ' \n'
#                                    '了\n'
#                                    '解\n'
#                                    '内\n'
#                                    '容\n'
#                                    '，\n'
#                                    '可\n'
#                                    '以\n'
#                                    '不\n'
#                                    '看\n'
#                                    '‘\n'
#                                    ' \n'
#                                    '团\n'
#                                    '队\n'
#                                    '主\n'
#                                    '要\n'
#                                    '工\n'
#                                    '作\n'
#                                    '流\n'
#                                    '工\n'
#                                    '作\n'
#                                    '流\n'
#                                    '接\n'
#                                    '口\n'
#                                    '人\n'
#                                    '文\n'
#                                    '档\n'
#                                    '\n'
#                                    '\n'
#                                    'ab\n'
#                                    '（\n'
#                                    'assetsbundle\n'
#                                    '）\n'
#                                    '包\n'
#                                    'Editor\n'
#                                    '中\n'
#                                    'package\n'
#                                    '资\n'
#                                    '源\n'
#                                    '包\n'
#                                    '团\n'
#                                    '队\n'
#                                    '开\n'
#                                    '发\n'
#                                    '美\n'
#                                    '术\n'
#                                    '资\n'
#                                    '源\n'
#                                    '验\n'
#                                    '收\n'
#                                    '功\n'
#                                    '能\n'
#                                    '验\n'
#                                    '收\n'
#                                    '系\n'
#                                    '统\n'
#                                    '建\n'
#                                    '造\n'
#                                    'Editor-A4\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    '美\n'
#                                    '术\n'
#                                    '纯\n'
#                                    '净\n'
#                                    '工\n'
#                                    '程\n'
#                                    'Editor-A4\n'
#                                    '工\n'
#                                    '程\n'
#                                    ' + \n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '关\n'
#                                    '卡\n'
#                                    'precheck\n'
#                                    '工\n'
#                                    '程\n'
#                                    '（\n'
#                                    '编\n'
#                                    '辑\n'
#                                    '地\n'
#                                    '图\n'
#                                    '）\n'
#                                    '美\n'
#                                    '术\n'
#                                    '纯\n'
#                                    '净\n'
#                                    '工\n'
#                                    '程\n'
#                                    'Editor-A4\n'
#                                    '工\n'
#                                    '程\n'
#                                    ' + \n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    '武\n'
#                                    '器\n'
#                                    '3C\n'
#                                    'Editor-A4\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    'Editor-A4\n'
#                                    '工\n'
#                                    '程\n'
#                                    '目\n'
#                                    '录\n'
#                                    'Editor-A4\n'
#                                    '工\n'
#                                    '程\n'
#                                    ' + \n'
#                                    '本\n'
#                                    '地\n'
#                                    '服\n'
#                                    'SOC-\n'
#                                    '接\n'
#                                    '口\n'
#                                    '人'},
#               'score': -0.0272921957,
#               'values': []}],
#  'namespace': 'soc-project'}

# %%
index = pinecone.Index("rules")
index.delete(deleteAll='true', namespace="soc-project-pdf")
# Out:
# {}
